# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MuneezaKhan01/flyrank-ml-internship/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*
#
# Unit of analysis: One row represents one content item for one client on one report date.
#
# Time window:The warehouse contains daily observations from January 2025 through June 2026. I will use March 2026 as the mid-panel month for development and verification, while treating June 2026 as the sealed outcome month.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*
#
# Features: `gsc_impressions`, `gsc_clicks`, `gsc_avg_position`, `ga4_sessions`, and `sessions_organic`. These describe content performance that can be observed at the decision moment.
#
# Label: Future `gsc_clicks`. This is the future search performance I want to predict or rank.
#
# Context: `report_date`, `client_hash_id`, `content_hash_id`, `client_has_gsc`, `client_has_ga4`, `gsc_data_available`, and `ga4_data_available`. These describe the content, client, date, and availability of the data.
#
# Excluded: Future performance information and any fields derived from the future label. I exclude them because they would give the model information that would not be available at the decision moment and would cause data leakage.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

#query 1
grain_check = march_df.groupby(
    ["report_date", "client_hash_id", "content_hash_id"]
).size()
print("Total rows:", len(march_df))
print("Unique client-content-date combinations:", len(grain_check))
print("Maximum rows per combination:", grain_check.max())
print("Combinations with more than one row:", (grain_check > 1).sum())

#query 2
march_df["report_date"] = pd.to_datetime(march_df["report_date"])

print("Row count:", len(march_df))
print("Start date:", march_df["report_date"].min())
print("End date:", march_df["report_date"].max())

#query 3
available_gsc = march_df[march_df["gsc_data_available"] == True]

print("Rows before availability filter:", len(march_df))
print("Rows where GSC data is available:", len(available_gsc))
# Out:
# Total rows: 9841378
# Unique client-content-date combinations: 9841378
# Maximum rows per combination: 1
# Combinations with more than one row: 0
# Row count: 9841378
# Start date: 2026-03-01 00:00:00
# End date: 2026-03-31 00:00:00
# Rows before availability filter: 9841378
# Rows where GSC data is available: 3611061

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*
#
#
# This data cannot give a fully balanced view of every client because clients may have different amounts of history and different data sources available. Some observations have GSC data but no GA4 data. Therefore, comparisons across clients should be treated as directional decision-support, not as a complete measure of performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Query 2: Verify row count and date span

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
